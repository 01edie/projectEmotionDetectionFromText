# %%
import pandas as pd

# %%
df=pd.read_csv('d0.csv')

# %%
df.head()
# Out:
#   id                                            content sentiment
# 0  1                                    শুভ নববর্ষ ১৪২৯  positive
# 1  2  ইংরেজি গ্রামারের সম্পূর্ণ হ্যান্ডনোট। আশা করি ...  positive
# 2  3                              আমি মাঠে খেলতে যাচ্ছি  positive
# 3  4                           আমি ফুটবল খেলা পছন্দ করি  positive
# 4  5                  বার্সালোনা আমার প্রিয় ফুটবল ক্লাব  positive

# %%
#tokenizing every word
total_tokens = []
unique_tokens = []
i=0;
while i< len(df):
    a=str(df['content'][i]).split(" ")
    unique_tokens = set(unique_tokens).union(set(a))
    total_tokens +=a
    i +=1
print(len(total_tokens))
print(len(unique_tokens))
print(type(total_tokens))
print(type(unique_tokens))
# Out:
# 3204
# 1638
# <class 'list'>
# <class 'set'>

# %%
#term count
word_count_dict = {}

for word in unique_tokens:
    key = word
    value = total_tokens.count(word)
    word_count_dict[key] = value
print(word_count_dict)
# Out:
# {'': 9, 'রাখলেও': 1, 'বাঙালির': 2, 'কষ্ট': 3, 'দিনগুলো': 1, 'উৎসাহব্যঞ্জক': 1, 'বলতেই': 1, 'শোকাহত': 1, 'পশ্চিমবঙ্গের': 2, 'কথা': 10, 'BBC': 1, 'রানের': 1, 'আমরা': 12, 'শেষবার': 1, 'কেজির': 1, 'বিষয়ে': 1, 'ওয়াও...': 1, 'মাসের': 1, 'করছে': 5, 'মুভিটি': 1, 'ইরান': 1, 'সেনা': 1, 'মেটানো': 1, 'একসাথে': 2, 'আনন্দময়': 1, 'পুরাতন।': 1, 'রয়েছে।': 2, 'গাছ': 1, 'শুরুয়াত।': 1, 'খুশি': 5, 'লেশন': 1, 'ভালো': 28, 'ভবন': 1, 'জটিল': 1, 'করা': 8, 'উচ্চতায়': 1, 'আয়ত্তে': 1, 'এক': 6, 'হয়': 9, 'ব্যাক্তিগত': 1, 'অসাধারণ': 10, 'সেটাই': 1, 'যাবে': 2, 'অ্যাপস': 1, 'আসল': 1, 'গেলো': 2, 'স্যলুট': 1, 'কৃষকের': 1, 'ছুটির': 1, 'ভাবনা': 1, 'মাদক': 1, 'স্মার্ট': 1, 'এগুলি': 2, 'হল': 3, 'যাওয়ার': 1, 'কিছুই': 5, 'ঢাকা': 1, 'মামা': 1, 'রং।': 1, 'মৃত্যুবরণ': 1, 'ফটোগ্রাফারের': 1, 'দেখবেন': 1, 'ভারী': 1, 'এর': 9, 'অপ্রিয়': 1, 'অপমৃত্যু': 1, 'সরকার': 1, 'প্রকৃতির': 2, 'আপনাকে': 2, 'ধরে': 2, 'নেয়া': 1, 'ফসিল্\u200cস': 1, 'ফেলেছে': 1, 'পচা': 1, 'সেম': 1, 'অভিশপ্ত': 1, 'শাক্ষি': 1, 'মাঠে': 1, 'স্বাধীনতা,মতামত': 1, 'লিখেছিলাম': 1, 'বোধহ
1, 'জায়গা': 2, 'চাইছে': 1, 'এদেরকে': 1, 'সুন্দরভাবে': 3, 'আশা': 4, 'দাদা': 1, 'চাকরি': 2, 'কাশ্মীরের': 1, 'সদয়': 1, 'গিয়েছিলাম': 1, 'প্রদীপ': 1, 'একে': 1, 'কতদিন': 1, 'করুন': 3, 'বিশেষ': 2, 'কাঁদছিল': 1, 'স্পেনকে': 1, 'সম্ভাব্য': 1, 'অগ্রহণযোগ্য': 1, 'কোন': 7, 'রেখে': 2, 'এমনই': 2, '১৭০': 1, 'কাটুক': 1, 'জানতানা': 1, 'থাক': 4, 'ভালোবাসা': 5, 'ব্যস্ত': 1, 'স্টার': 1, 'ক্ষমতার': 1, 'মূলত': 1, 'যে': 14, 'করছিলাম': 3, 'তত': 1, 'ট্যাগ': 1, 'নিয়ে': 3, 'টেস্ট': 1, 'উস্কানি': 1, 'মতো': 4, 'যাপন': 1, 'ফেরার': 1, 'বৃষ্টি': 1, 'বিবাহবার্ষিকী': 1, 'সিং-এর': 1, 'বেদনাদায়ক': 2, 'ভাবেই': 1, 'প্রতিভাবান': 1, 'অদ্ভুত': 1, 'পৃথিবীর': 3, 'সম্মানিত': 1, 'গত': 3, '6': 1, 'বরষা': 1, 'ডেন্টিস্টকে': 1, 'এইমাত্র': 2, 'ছবির': 2, 'সেখানেই': 1, 'সার্থ্য': 1, 'ল্যাম্পপোষ্ট': 1, 'আছে': 5, 'technology': 1, 'পর': 3, 'দূর্ভাগ্য': 1, 'অপেক্ষা': 1, 'একটু': 4, 'মানসিক': 4, 'দাঁতের': 1, 'পক্ষে': 1, 'বর্তমানে': 1, 'আত্মঘাতী': 1, 'সাধুবাদ': 1, 'বার': 1, 'দুর্দান্ত': 2, 'জগতে': 1, 'জায়গাটি': 1, 'তোমাদেরকে': 1, 'সেদিকে': 1, 'করে': 23, 'আসলে': 2, 'কখনও': 2, 'বলে': 5, 'হবে': 7, 'যদি': 4, 'পাচ্ছি': 2, 'শক্তির': 1, 'করবেন': 2, 'ফুল': 3, 'বানাচ্ছেন': 1, 'ছবি,': 1, 'একদম': 1, 'জন্য!': 1, 'মানায়': 1, 'ফিরে': 5, 'সমুজ্জ্বল': 1, 'জন্য।': 1, 'থাকবেন': 1, 'থাকার': 1, 'প্যাটার্নে': 1, 'চিরকাল': 1, 'জব': 1, 'বন্ধুদের': 1, 'উদ্বেগ': 1, 'সেবন': 1, 'সাধারণ': 1, 'সময়': 2, 'অপার': 2, 'স্বাচ্ছন্দ্য': 1, 'হ্যান্ডনোট।': 1, 'পেয়ে': 1, 'শিয়রে': 1, 'একদিন': 1, ...

# %%
#eleminating the words of word count more than 30
final_tokens = []
print('removed words: ')
for word in unique_tokens:
    if(word_count_dict[word]<30):
        final_tokens.append(word)
    else:
        print(word)
#print(final_tokens)
print(len(final_tokens))
# Out:
# removed words:
# করে
# ও
# এটি
# বোধ
# ভাল
# করছি
# যে
# করতে
# মনে
# এই
# অসাধারণ
# ভালো
# সব
# জন্য
# আমরা
# এটা
# খুব
# আর
# না
# এ
# খারাপ
# একটা
# সুন্দর
# আমি
# তো
# অনেক
# এবং
# তার
# এখন
# সাথে
# কিছু
# কথা
# আমাদের
# আমার
# একটি
# কে
# করি
# মানুষ
# 1600

# %%
#breaking down into positive, negative and neutral parts
tmp_positive_tokens = []
tmp_negative_tokens = []
tmp_neutral_tokens = []
i=0
while i < len(df):
    if(df['sentiment'][i]=='positive'):
        tmp_positive_tokens += (df['content'][i].split())
    elif(df['sentiment'][i]=='negative'):
        tmp_negative_tokens += (df['content'][i].split())
    elif(df['sentiment'][i]=='neutral'):
        tmp_neutral_tokens += (df['content'][i].split())
    i += 1

# %%
#cutting off or filtering off the unnecessary words
positive_tokens = []
print(len(final_tokens))
print('____________')
negative_tokens = []
neutral_tokens = []
for word in tmp_positive_tokens:
    if(final_tokens.count(word) and (positive_tokens.count(word)==0)):
        positive_tokens.append(word)
for word in tmp_negative_tokens:
    if(final_tokens.count(word) and (negative_tokens.count(word)==0)):
        negative_tokens.append(word)
for word in tmp_neutral_tokens:
    if(final_tokens.count(word) and (neutral_tokens.count(word)==0)):
        neutral_tokens.append(word)

print(len(tmp_positive_tokens))
print(len(positive_tokens))

print(len(tmp_negative_tokens))
print(len(negative_tokens))

print(len(tmp_neutral_tokens))
print(len(neutral_tokens))


# print(positive_tokens)
# Out:
# 1600
# ____________
# 1210
# 651
# 1288
# 716
# 693
# 497

# %%
#appending some key words
positive_tokens += ['ভাল','ভালো','অসাধারণ','সুন্দর'] 
negative_tokens += ['খারাপ','না']

# %%
#taking input and checking sentiment
text = input('enter your text!').split(' ')
pos_value = 0
neg_value = 0
neu_value = 0
for word in text:
    pos_value += positive_tokens.count(word)
    neg_value += negative_tokens.count(word)
    neu_value += neutral_tokens.count(word)
print('pos: ' ,pos_value)
print('neg: ' , neg_value)
print('neu: ' , neu_value)
if (pos_value > neg_value and pos_value > neu_value):
    print("it seems like a positive sentence")
elif(pos_value==0 and neg_value==0 and neu_val == 0):
    print("it seems like a neutral vibe")
elif(neg_value >= pos_value and neg_value >= neu_value):
    print("it seems like a negative sentence")
else:
    print("it seems like a neutral vibe")
# Out:
# enter your text!  গানটা ভালো
# pos:  1
# neg:  0
# neu:  0
# it seems like a positive sentence

# %%
#some results
# আমি এটা পছন্দ করি না - it seems like a negative sentence
# আপনি ব্যার্থ,অযোগ্য - it seems like a negative sentence
# এটা চমৎকার - it seems like a positive sentence
# আবহাওয়া ভালো - it seems like a positive sentence
# এটা কোন মানসম্মত যুক্তি নয় - it seems like a negative sentence
# দারুন স্বাদ - it seems like a positive sentence
# আমি জানি না - it seems like a negative sentence
# তুমি কি করবে - it seems like a negative sentence !
#গানটা ভালো - it seems like a positive sentence
